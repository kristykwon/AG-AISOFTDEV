# %% [markdown]
# # Day 1 - Lab 2: Generating a Product Requirements Document (PRD)
#
# **Objective:** Use the structured `day1_user_stories.json` artifact from the previous lab to generate a formal, comprehensive Product Requirements Document (PRD) in markdown format.
#
# **Estimated Time:** 60 minutes
#
# **Introduction:**
# With a validated set of user stories, we can now create a higher-level planning document: the PRD. A PRD serves as the source of truth for the product team, outlining the project's purpose, features, and requirements. In this lab, you will use an LLM to synthesize the detailed user stories into this formal document.
#
# For definitions of key terms used in this lab, please refer to the [GLOSSARY.md](../../GLOSSARY.md).

# %% [markdown]
# ## Step 1: Setup
#
# This initial block sets up our environment. It adds the project's root directory to the Python path, allowing us to import our custom `utils.py` script. We then initialize the connection to our Large Language Model (LLM) and load the JSON artifact from the previous lab.
#
# **Model Selection:**
# You can change the `model_name` parameter in the `setup_llm_client()` function to any of the models listed in `utils.py`, such as `"gemini-2.5-flash"` or `"meta-llama/Llama-3.3-70B-Instruct"`.
#
# **Helper Functions Used:**
# - `setup_llm_client()`: To configure the API client.
# - `get_completion()`: To send prompts to the LLM.
# - `load_artifact()`: To read the user stories JSON file and the PRD template.
# - `save_artifact()`: To save our generated PRD and Pydantic model.

# %%
import sys
import os
import json

# Add the project's root directory to the Python path to ensure 'utils' can be imported.
try:
    # Assumes the notebook is in 'labs/Day_01_.../'
    project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
except IndexError:
    # Fallback for different execution environments
    project_root = os.path.abspath(os.path.join(os.getcwd()))

if project_root not in sys.path:
    sys.path.insert(0, project_root)

from utils import setup_llm_client, get_completion, save_artifact, load_artifact

# Initialize the LLM client. You can change the model here.
client, model_name, api_provider = setup_llm_client(model_name="gemini-2.5-pro")

# Load the artifact from Lab 1
user_stories_data = load_artifact("day1_user_stories.json") or []
# Out:
# 2025-10-27 17:17:07,970 ag_aisoftdev.utils INFO LLM Client configured provider=google model=gemini-2.5-pro latency_ms=None artifacts_path=None

# %% [markdown]
# ## Step 2: The Challenges

# %% [markdown]
# ### Challenge 1 (Foundational): Generating a Simple PRD
#
# **Task:** Use the loaded user stories to generate a simple PRD.
#
# **Instructions:**
# 1. Create a prompt that instructs the LLM to act as a Product Manager.
# 2. Provide the `user_stories_data` as context.
# 3. Ask the LLM to generate a PRD with three sections: "Introduction", "User Personas", and "Features / User Stories".
#
# **Expected Quality:** A clean markdown document that correctly summarizes the provided user stories into the requested sections.

# %%
# TWrite a prompt to generate a simple PRD.
simple_prd_prompt = f"""
You are a Product Manager writing a Product Requirements Document (PRD) for a new hire onboarding tool.

Use the following JSON data containing user stories as your primary source of information:
<user_stories>
{user_stories_data}
</user_stories>

Generate a PRD in markdown format with the following sections:
1. **Introduction:** A brief overview of the project's purpose.
2. **User Personas:** A summary of the key users involved.
3. **Features / User Stories:** A list of the user stories and their acceptance criteria.
"""

print("--- Generating Simple PRD ---")
# if user_stories_data:
#     # Enhance the prompt to improve structure and consistency
#     enhanced_simple_prd_prompt = prompt_enhancer(simple_prd_prompt)
#     print("Enhanced Simple PRD prompt:\n", enhanced_simple_prd_prompt)
#     simple_prd_output = get_completion(enhanced_simple_prd_prompt, client, model_name, api_provider)
#     print(simple_prd_output)
# else:
#     print("Skipping PRD generation because user stories are missing.")

if user_stories_data:
    simple_prd_output = get_completion(simple_prd_prompt, client, model_name, api_provider)
    print(simple_prd_output)
else:
    print("Skipping PRD generation because user stories are missing.")
# Out:
# --- Generating Simple PRD ---
# # Product Requirements Document: New Hire Onboarding Tool
#
# ## 1. Introduction
#
# This document outlines the product requirements for a new, comprehensive onboarding tool. The purpose of this project is to create a centralized platform that streamlines the new hire experience, reduces administrative burden on HR and hiring managers, and fosters a sense of belonging for new employees before their first day. By automating tasks, providing clear visibility into progress, and facilitating early connections, this tool aims to deliver a consistent, efficient, and engaging onboarding journey for everyone involved.
#
# ---
#
# ## 2. User Personas
#
# The key users of this platform are defined by the following personas:
#
# *   **Alex Chen (The Anxious New Hire):** Eager to make a good impression and wants to get administrative tasks out of the way. Values feeling prepared and connected to their new team before day one.
# *   **Sarah Rodriguez (The Busy Hiring Manager):** Responsible for her new hire's success but juggles many priorities. Needs a quick, at-a-glance way to track progress and complete her own onboarding tasks without constant follow-up.
# *   **David Miller (The Process-Driven HR Administrator):** Manages onboarding for the entire company. Requires tools to create consistent, repeatable, and role-specific onboarding plans to ensure compliance and a high-quality experience for all.
#
# ---
#
# ## 3. Features / User Stories
#
# This section details the core features of the onboarding tool, derived from user stories and their specific acceptance criteria.
#
# ### Feature 1: Digital Paperwork Completion (Alex Chen)
#
# > **As an Anxious New Hire, I want to complete all my HR paperwork digitally before my first day, so that I can focus on meeting my team and learning my role when I start.**
#
# **Acceptance Criteria:**
# *   Given I am a new hire who has received my pre-boarding link, When I log in for the first time, Then I am directed to a secure document hub.
# *   Given I am in the document hub, When I open a form like a W-4 or I-9, Then I can fill out all required fields directly in the browser.
# *   Given a form requires a signature, When I click the signature field, Then I can use an e-signature tool to sign the document.
# *   Given I have submitted all my documents, When I view my main onboarding checklist, Then the 'Complete Paperwork' task is marked as complete.
#
# ### Feature 2: Manager Onboarding Dashboard (Sarah Rodriguez)
#
# > **As a Busy Hiring Manager, I want to see a dashboard overview of my new hire's onboarding progress, so that I can quickly identify where they are and what my responsibilities are without constant check-ins.**
#
# **Acceptance Criteria:**
# *   Given I am a manager with a new hire, When I log into the onboarding tool, Then I see a 'My New Hires' dashboard.
# *   Given I am on the dashboard, When I view my new hire's profile, Then I see a visual progress bar indicating their overall completion percentage.
# *   Given the new hire has completed a task, When I refresh my dashboard, Then the task list and progress bar are updated in near real-time.
# *   Given a task requires my action (e.g., 'Approve equipment request'), When I view the dashboard, Then that task is clearly highlighted in a 'My Tasks' section.
#
# ### Feature 3: Customizable Onboarding Templates (David Miller)
#
# > **As a Process-Driven HR Administrator, I want to create and customize role-based onboarding templates, so that I can ensure a consistent and relevant experience for every new hire across the company.**
#
# **Acceptance Criteria:**
# *   Given I am an HR Admin logged into the admin panel, When I navigate to 'Onboarding Plans', Then I see a list of existing templates and a button to 'Create New Template'.
# *   Given I am creating a new template for 'Sales Development Rep', When I add tasks, Then I can assign each task to a specific role (New Hire, Manager, IT, HR).
# *   Given I have saved the template, When a new SDR is hired, Then I can assign the 'Sales Development Rep' template to their onboarding journey.
# *   Given a process changes, When I edit an existing template, Then the changes are applied only to new hires assigned that template going forward, not those already in progress.
#
# ### Feature 4: Meet the Team Module (Alex Chen)
#
# > **As an Anxious New Hire, I want to see photos and fun facts about my immediate team members before I start, so that I can feel more comfortable and familiar with them on my first day.**
#
# **Acceptance Criteria:**
# *   Given I am in the pre-boarding portal, When I click on the 'Meet Your Team' section, Then I see a page with photos, names, and job titles of my direct teammates.
# *   Given I am viewing the team page, When I hover over or click on a team member's profile, Then a pop-up or expanded view shows additional information like 'Ask me about...' or a fun fact.
# *   Given my manager has not yet populated the team information, When I view the 'Meet Your Team' page, Then I see a friendly message like 'Your manager is putting this together for you!'.
#
# ### Feature 5: Automated Meeting Scheduling (Sarah Rodriguez)
#
# > **As a Busy Hiring Manager, I want the tool to automatically suggest and help schedule critical introductory meetings, so that I don't forget these important connections and can save administrative time.**
#
# **Acceptance Criteria:**
# *   Given my new hire's onboarding plan includes 'Schedule 1:1 with Manager', When I view this task, Then there is a 'Schedule Now' button that integrates with the company calendar.
# *   Given I click 'Schedule Now', When the calendar interface opens, Then it shows mutually available time slots for me and my new hire.
# *   Given I select a time and confirm, When the meeting is created, Then the calendar invitation is sent to both of us and includes a pre-populated agenda template with suggested talking points.
# *   Given the meeting has been successfully scheduled, When I return to my dashboard, Then the 'Schedule 1:1' task is automatically marked as complete.
# # Product Requirements Document: New Hire Onboarding Tool
#
# ## 1. Introduction
#
# This document outlines the product requirements for a new, comprehensive onboarding tool. The purpose of this project is to create a centralized platform that streamlines the new hire experience, reduces administrative burden on HR and hiring managers, and fosters a sense of belonging for new employees before their first day. By automating tasks, providing clear visibility into progress, and facilitating early connections, this tool aims to deliver a consistent, efficient, and engaging onboarding journey for everyone involved.
#
# ---
#
# ## 2. User Personas
#
# The key users of this platform are defined by the following personas:
#
# *   **Alex Chen (The Anxious New Hire):** Eager to make a good impression and wants to get administrative tasks out of the way. Values feeling prepared and connected to their new team before day one.
# *   **Sarah Rodriguez (The Busy Hiring Manager):** Responsible for her new hire's success but juggles many priorities. Needs a quick, at-a-glance way to track progress and complete her own onboarding tasks without constant follow-up.
# *   **David Miller (The Process-Driven HR Administrator):** Manages onboarding for the entire company. Requires tools to create consistent, repeatable, and role-specific onboarding plans to ensure compliance and a high-quality experience for all.
#
# ---
#
# ## 3. Features / User Stories
#
# This section details the core features of the onboarding tool, derived from user stories and their specific acceptance criteria.
#
# ### Feature 1: Digital Paperwork Completion (Alex Chen)
#
# > **As an Anxious New Hire, I want to complete all my HR paperwork digitally before my first day, so that I can focus on meeting my team and learning my role when I start.**
#
# **Acceptance Criteria:**
# *   Given I am a new hire who has received my pre-boarding link, When I log in for the first time, Then I am directed to a secure document hub.
# *   Given I am in the document hub, When I open a form like a W-4 or I-9, Then I can fill out all required fields directly in the browser.
# *   Given a form requires a signature, When I click the signature field, Then I can use an e-signature tool to sign the document.
# *   Given I have submitted all my documents, When I view my main onboarding checklist, Then the 'Complete Paperwork' task is marked as complete.
#
# ### Feature 2: Manager Onboarding Dashboard (Sarah Rodriguez)
#
# > **As a Busy Hiring Manager, I want to see a dashboard overview of my new hire's onboarding progress, so that I can quickly identify where they are and what my responsibilities are without constant check-ins.**
#
# **Acceptance Criteria:**
# *   Given I am a manager with a new hire, When I log into the onboarding tool, Then I see a 'My New Hires' dashboard.
# *   Given I am on the dashboard, When I view my new hire's profile, Then I see a visual progress bar indicating their overall completion percentage.
# *   Given the new hire has completed a task, When I refresh my dashboard, Then the task list and progress bar are updated in near real-time.
# *   Given a task requires my action (e.g., 'Approve equipment request'), When I view the dashboard, Then that task is clearly highlighted in a 'My Tasks' section.
#
# ### Feature 3: Customizable Onboarding Templates (David Miller)
#
# > **As a Process-Driven HR Administrator, I want to create and customize role-based onboarding templates, so that I can ensure a consistent and relevant experience for every new hire across the company.**
#
# **Acceptance Criteria:**
# *   Given I am an HR Admin logged into the admin panel, When I navigate to 'Onboarding Plans', Then I see a list of existing templates and a button to 'Create New Template'.
# *   Given I am creating a new template for 'Sales Development Rep', When I add tasks, Then I can assign each task to a specific role (New Hire, Manager, IT, HR).
# *   Given I have saved the template, When a new SDR is hired, Then I can assign the 'Sales Development Rep' template to their onboarding journey.
# *   Given a process changes, When I edit an existing template, Then the changes are applied only to new hires assigned that template going forward, not those already in progress.
#
# ### Feature 4: Meet the Team Module (Alex Chen)
#
# > **As an Anxious New Hire, I want to see photos and fun facts about my immediate team members before I start, so that I can feel more comfortable and familiar with them on my first day.**
#
# **Acceptance Criteria:**
# *   Given I am in the pre-boarding portal, When I click on the 'Meet Your Team' section, Then I see a page with photos, names, and job titles of my direct teammates.
# *   Given I am viewing the team page, When I hover over or click on a team member's profile, Then a pop-up or expanded view shows additional information like 'Ask me about...' or a fun fact.
# *   Given my manager has not yet populated the team information, When I view the 'Meet Your Team' page, Then I see a friendly message like 'Your manager is putting this together for you!'.
#
# ### Feature 5: Automated Meeting Scheduling (Sarah Rodriguez)
#
# > **As a Busy Hiring Manager, I want the tool to automatically suggest and help schedule critical introductory meetings, so that I don't forget these important connections and can save administrative time.**
#
# **Acceptance Criteria:**
# *   Given my new hire's onboarding plan includes 'Schedule 1:1 with Manager', When I view this task, Then there is a 'Schedule Now' button that integrates with the company calendar.
# *   Given I click 'Schedule Now', When the calendar interface opens, Then it shows mutually available time slots for me and my new hire.
# *   Given I select a time and confirm, When the meeting is created, Then the calendar invitation is sent to both of us and includes a pre-populated agenda template with suggested talking points.
# *   Given the meeting has been successfully scheduled, When I return to my dashboard, Then the 'Schedule 1:1' task is automatically marked as complete.

# %% [markdown]
# ### Challenge 2 (Intermediate): Generating a PRD from a Template
#
# **Task:** Instead of just listing sections, we will now provide the LLM with a formal template to ensure the PRD's structure is consistent and complete.
#
# **Instructions:**
# 1. First, load the contents of `templates/prd_template.md` into a variable.
# 2. Create a new prompt that instructs the LLM to act as a Senior Product Manager.
# 3. Provide both the `user_stories_data` and the `prd_template_content` as context.
# 4. Instruct the LLM to populate the template with the information from the user stories, ensuring every section of the template is filled out.
#
# > **Tip:** The template has sections like 'Success Metrics' and 'Out of Scope' that aren't in the user stories. This is your chance to guide the LLM's creativity! Instruct it to infer logical content for these sections based on the project's overall goal.
#
# **Expected Quality:** A complete PRD that strictly follows the structure of the provided template file, demonstrating the LLM's ability to perform structured content generation.

# %%
# Load the PRD template
# prd_template_content = load_artifact("templates/prd_template.md")
prd_template_content = load_artifact("prd_template.md", base_dir=os.path.join(project_root, "templates"))

# Ensure we have a JSON string version of the user stories for use in prompts/templates
if isinstance(user_stories_data, (list, dict)):
    user_stories_str = json.dumps(user_stories_data, indent=2)
else:
    user_stories_str = user_stories_data or "[]"

# TWrite a prompt to populate the PRD template.
template_prd_prompt = f"""
You are a Senior Product Manager responsible for creating a detailed and formal Product Requirements Document (PRD).

Your task is to populate the provided PRD template using the information from the user stories JSON.

<prd_template>
{prd_template_content}
</prd_template>

<user_stories_json>
{user_stories_str}
</user_stories_json>

Fill out every section of the template. For sections like 'Success Metrics' or 'Out of Scope', you must infer reasonable content based on the user stories and the overall project goal of creating a new hire onboarding tool.
The final output should be the completed PRD in markdown format.
"""

print("--- Generating PRD from Template ---")
if user_stories_data and prd_template_content:
    prd_from_template_output = get_completion(template_prd_prompt, client, model_name, api_provider)
    print(prd_from_template_output)
else:
    print("Skipping PRD generation because user stories or template are missing.")
    prd_from_template_output = ""
# Out:
# --- Generating PRD from Template ---
# # Product Requirements Document: WelcomePath: New Hire Onboarding Platform
#
# | Status | **Draft** |
# | :--- | :--- |
# | **Author** | Product Team Alpha |
# | **Version** | 1.0 |
# | **Last Updated** | 2023-10-27 |
#
# ## 1. Executive Summary & Vision
# WelcomePath is a centralized, digital onboarding platform designed to streamline the new hire experience from the moment an offer is accepted. We are building it to solve the problem of fragmented, manual, and inconsistent onboarding processes that create anxiety for new hires and administrative burdens for managers and HR. The vision for WelcomePath is to become the single source of truth for onboarding, fostering a welcoming and engaging environment that accelerates new hire productivity and integration into the company culture.
#
# ## 2. The Problem
# *A detailed look at the pain points this product will solve. This section justifies the project's existence.*
#
# **2.1. Problem Statement:**
# New hires currently face a disconnected and paper-heavy onboarding process, leading to first-day anxiety, reduced initial productivity, and significant administrative overhead for managers and HR teams. This lack of a centralized system results in inconsistent experiences across departments and missed opportunities to engage new employees effectively from the moment they accept their offer.
#
# **2.2. User Personas & Scenarios:**
# [Summarize the key user personas affected by this problem. For each persona, describe a typical scenario they face that highlights the problem.]
#
# - **Persona 1: Alex Chen, The Anxious New Hire**
#     - **Scenario:** Alex has just accepted a job offer. He receives multiple emails with different PDF forms to print, sign, scan, and email back. He isn't sure who is on his team and feels disconnected, leading to anxiety about his first day. He wants a clear, single place to see what he needs to do and to learn about his new colleagues.
#
# - **Persona 2: Sarah Rodriguez, The Busy Hiring Manager**
#     - **Scenario:** Sarah is excited to have a new person joining her team, but she is swamped with her own project deadlines. She struggles to remember all the onboarding tasks she's responsible for, like scheduling introductory meetings and ensuring equipment is ordered. She has no easy way to track her new hire's progress without sending multiple "just checking in" emails.
#
# - **Persona 3: David Miller, The Process-Driven HR Administrator**
#     - **Scenario:** David is responsible for ensuring every new hire gets a consistent, compliant onboarding experience. He manually creates and emails different task checklists for different roles (e.g., Engineer vs. Sales). When a company policy changes, he has to update several different document templates and hopes managers use the most recent version.
#
# ## 3. Goals & Success Metrics
# *How will we measure success? This section defines the specific, measurable outcomes we expect.*
#
# | Goal | Key Performance Indicator (KPI) | Target |
# | :--- | :--- | :--- |
# | Improve New Hire Efficiency | Reduce time-to-first-contribution | Decrease by 20% in Q1 |
# | Reduce Support Load | Decrease repetitive onboarding questions to HR | 30% reduction in support tickets |
# | Increase Engagement | Onboarding checklist completion rate | Achieve 95% completion rate |
#
# ## 4. Functional Requirements & User Stories
# *The core of the PRD. This section details what the product must do, broken down into actionable user stories.*
#
# ---
# **Epic: New Hire Pre-boarding Experience**
#
# *   **Story 1.1:** As an Anxious New Hire, I want to complete all my HR paperwork digitally before my first day, so that I can focus on meeting my team and learning my role when I start.
#     *   **Acceptance Criteria:**
#         *   **Given** I am a new hire who has received my pre-boarding link, **When** I log in for the first time, **Then** I am directed to a secure document hub.
#         *   **Given** I am in the document hub, **When** I open a form like a W-4 or I-9, **Then** I can fill out all required fields directly in the browser.
#         *   **Given** a form requires a signature, **When** I click the signature field, **Then** I can use an e-signature tool to sign the document.
#         *   **Given** I have submitted all my documents, **When** I view my main onboarding checklist, **Then** the 'Complete Paperwork' task is marked as complete.
#
# *   **Story 1.2:** As an Anxious New Hire, I want to see photos and fun facts about my immediate team members before I start, so that I can feel more comfortable and familiar with them on my first day.
#     *   **Acceptance Criteria:**
#         *   **Given** I am in the pre-boarding portal, **When** I click on the 'Meet Your Team' section, **Then** I see a page with photos, names, and job titles of my direct teammates.
#         *   **Given** I am viewing the team page, **When** I hover over or click on a team member's profile, **Then** a pop-up or expanded view shows additional information like 'Ask me about...' or a fun fact.
#         *   **Given** my manager has not yet populated the team information, **When** I view the 'Meet Your Team' page, **Then** I see a friendly message like 'Your manager is putting this together for you!'.
#
# ---
# **Epic: Manager Onboarding Oversight**
#
# *   **Story 2.1:** As a Busy Hiring Manager, I want to see a dashboard overview of my new hire's onboarding progress, so that I can quickly identify where they are and what my responsibilities are without constant check-ins.
#     *   **Acceptance Criteria:**
#         *   **Given** I am a manager with a new hire, **When** I log into the onboarding tool, **Then** I see a 'My New Hires' dashboard.
#         *   **Given** I am on the dashboard, **When** I view my new hire's profile, **Then** I see a visual progress bar indicating their overall completion percentage.
#         *   **Given** the new hire has completed a task, **When** I refresh my dashboard, **Then** the task list and progress bar are updated in near real-time.
#         *   **Given** a task requires my action (e.g., 'Approve equipment request'), **When** I view the dashboard, **Then** that task is clearly highlighted in a 'My Tasks' section.
#
# *   **Story 2.2:** As a Busy Hiring Manager, I want the tool to automatically suggest and help schedule critical introductory meetings, so that I don't forget these important connections and can save administrative time.
#     *   **Acceptance Criteria:**
#         *   **Given** my new hire's onboarding plan includes 'Schedule 1:1 with Manager', **When** I view this task, **Then** there is a 'Schedule Now' button that integrates with the company calendar.
#         *   **Given** I click 'Schedule Now', **When** the calendar interface opens, **Then** it shows mutually available time slots for me and my new hire.
#         *   **Given** I select a time and confirm, **When** the meeting is created, **Then** the calendar invitation is sent to both of us and includes a pre-populated agenda template with suggested talking points.
#         *   **Given** the meeting has been successfully scheduled, **When** I return to my dashboard, **Then** the 'Schedule 1:1' task is automatically marked as complete.
#
# ---
# **Epic: HR Admin Process Management**
#
# *   **Story 3.1:** As a Process-Driven HR Administrator, I want to create and customize role-based onboarding templates, so that I can ensure a consistent and relevant experience for every new hire across the company.
#     *   **Acceptance Criteria:**
#         *   **Given** I am an HR Admin logged into the admin panel, **When** I navigate to 'Onboarding Plans', **Then** I see a list of existing templates and a button to 'Create New Template'.
#         *   **Given** I am creating a new template for 'Sales Development Rep', **When** I add tasks, **Then** I can assign each task to a specific role (New Hire, Manager, IT, HR).
#         *   **Given** I have saved the template, **When** a new SDR is hired, **Then** I can assign the 'Sales Development Rep' template to their onboarding journey.
#         *   **Given** a process changes, **When** I edit an existing template, **Then** the changes are applied only to new hires assigned that template going forward, not those already in progress.
#
# ---
#
# ## 5. Non-Functional Requirements (NFRs)
# *The qualities of the system. These are just as important as the functional requirements.*
#
# - **Performance:** The application must load in under 3 seconds on a standard corporate network connection.
# - **Security:** All user data, especially PII, must be encrypted in transit and at rest. The system must comply with company SSO policies for authentication.
# - **Accessibility:** The user interface must be compliant with WCAG 2.1 AA standards to ensure usability for all employees.
# - **Scalability:** The system must support up to 500 concurrent users during peak onboarding seasons (e.g., post-university graduation hiring).
#
# ## 6. Release Plan & Milestones
# *A high-level timeline for delivery.*
#
# - **Version 1.0 (MVP):** [Target Date: Q1 End] - Core features establishing the basic workflow: digital paperwork submission, manager progress dashboard, and HR admin template creation. (Covers Stories 1.1, 2.1, 3.1)
# - **Version 1.1:** [Target Date: Q2 Mid] - Enhanced engagement features: "Meet the Team" profiles and calendar integration for automated meeting scheduling. (Covers Stories 1.2, 2.2)
# - **Version 2.0:** [Target Date: Q4 End] - Full social engagement and gamification elements to further enhance the new hire experience.
#
# ## 7. Out of Scope & Future Considerations
# *What this product is **not**. This section is critical for managing expectations and preventing scope creep.*
#
# **7.1. Out of Scope for V1.0:**
# - Direct integration with third-party HR payroll systems (data will be managed via CSV export/import initially).
# - A native mobile application (the web application will be mobile-responsive).
# - Advanced analytics dashboard for managers beyond basic completion tracking.
#
# **7.2. Future Work:**
# - Integration with the corporate Learning Management System (LMS) to assign initial training modules.
# - AI-powered personalized onboarding paths based on role and pre-hire survey results.
# - A buddy/mentorship assignment and tracking module.
#
# ## 8. Appendix & Open Questions
# *A place to track dependencies, assumptions, and questions that need answers.*
#
# - **Open Question:** Which team (HR or Hiring Manager) will be responsible for populating and maintaining the content in the "Meet Your Team" sections?
# - **Dependency:** The final UI/UX design mockups for the dashboard and paperwork hub are required from the Design team by [Date: 2 weeks from today].
# - **Assumption:** The company's standard calendar API (e.g., Google Calendar, Outlook) is available and accessible for the meeting scheduling integration.
# # Product Requirements Document: WelcomePath: New Hire Onboarding Platform
#
# | Status | **Draft** |
# | :--- | :--- |
# | **Author** | Product Team Alpha |
# | **Version** | 1.0 |
# | **Last Updated** | 2023-10-27 |
#
# ## 1. Executive Summary & Vision
# WelcomePath is a centralized, digital onboarding platform designed to streamline the new hire experience from the moment an offer is accepted. We are building it to solve the problem of fragmented, manual, and inconsistent onboarding processes that create anxiety for new hires and administrative burdens for managers and HR. The vision for WelcomePath is to become the single source of truth for onboarding, fostering a welcoming and engaging environment that accelerates new hire productivity and integration into the company culture.
#
# ## 2. The Problem
# *A detailed look at the pain points this product will solve. This section justifies the project's existence.*
#
# **2.1. Problem Statement:**
# New hires currently face a disconnected and paper-heavy onboarding process, leading to first-day anxiety, reduced initial productivity, and significant administrative overhead for managers and HR teams. This lack of a centralized system results in inconsistent experiences across departments and missed opportunities to engage new employees effectively from the moment they accept their offer.
#
# **2.2. User Personas & Scenarios:**
# [Summarize the key user personas affected by this problem. For each persona, describe a typical scenario they face that highlights the problem.]
#
# - **Persona 1: Alex Chen, The Anxious New Hire**
#     - **Scenario:** Alex has just accepted a job offer. He receives multiple emails with different PDF forms to print, sign, scan, and email back. He isn't sure who is on his team and feels disconnected, leading to anxiety about his first day. He wants a clear, single place to see what he needs to do and to learn about his new colleagues.
#
# - **Persona 2: Sarah Rodriguez, The Busy Hiring Manager**
#     - **Scenario:** Sarah is excited to have a new person joining her team, but she is swamped with her own project deadlines. She struggles to remember all the onboarding tasks she's responsible for, like scheduling introductory meetings and ensuring equipment is ordered. She has no easy way to track her new hire's progress without sending multiple "just checking in" emails.
#
# - **Persona 3: David Miller, The Process-Driven HR Administrator**
#     - **Scenario:** David is responsible for ensuring every new hire gets a consistent, compliant onboarding experience. He manually creates and emails different task checklists for different roles (e.g., Engineer vs. Sales). When a company policy changes, he has to update several different document templates and hopes managers use the most recent version.
#
# ## 3. Goals & Success Metrics
# *How will we measure success? This section defines the specific, measurable outcomes we expect.*
#
# | Goal | Key Performance Indicator (KPI) | Target |
# | :--- | :--- | :--- |
# | Improve New Hire Efficiency | Reduce time-to-first-contribution | Decrease by 20% in Q1 |
# | Reduce Support Load | Decrease repetitive onboarding questions to HR | 30% reduction in support tickets |
# | Increase Engagement | Onboarding checklist completion rate | Achieve 95% completion rate |
#
# ## 4. Functional Requirements & User Stories
# *The core of the PRD. This section details what the product must do, broken down into actionable user stories.*
#
# ---
# **Epic: New Hire Pre-boarding Experience**
#
# *   **Story 1.1:** As an Anxious New Hire, I want to complete all my HR paperwork digitally before my first day, so that I can focus on meeting my team and learning my role when I start.
#     *   **Acceptance Criteria:**
#         *   **Given** I am a new hire who has received my pre-boarding link, **When** I log in for the first time, **Then** I am directed to a secure document hub.
#         *   **Given** I am in the document hub, **When** I open a form like a W-4 or I-9, **Then** I can fill out all required fields directly in the browser.
#         *   **Given** a form requires a signature, **When** I click the signature field, **Then** I can use an e-signature tool to sign the document.
#         *   **Given** I have submitted all my documents, **When** I view my main onboarding checklist, **Then** the 'Complete Paperwork' task is marked as complete.
#
# *   **Story 1.2:** As an Anxious New Hire, I want to see photos and fun facts about my immediate team members before I start, so that I can feel more comfortable and familiar with them on my first day.
#     *   **Acceptance Criteria:**
#         *   **Given** I am in the pre-boarding portal, **When** I click on the 'Meet Your Team' section, **Then** I see a page with photos, names, and job titles of my direct teammates.
#         *   **Given** I am viewing the team page, **When** I hover over or click on a team member's profile, **Then** a pop-up or expanded view shows additional information like 'Ask me about...' or a fun fact.
#         *   **Given** my manager has not yet populated the team information, **When** I view the 'Meet Your Team' page, **Then** I see a friendly message like 'Your manager is putting this together for you!'.
#
# ---
# **Epic: Manager Onboarding Oversight**
#
# *   **Story 2.1:** As a Busy Hiring Manager, I want to see a dashboard overview of my new hire's onboarding progress, so that I can quickly identify where they are and what my responsibilities are without constant check-ins.
#     *   **Acceptance Criteria:**
#         *   **Given** I am a manager with a new hire, **When** I log into the onboarding tool, **Then** I see a 'My New Hires' dashboard.
#         *   **Given** I am on the dashboard, **When** I view my new hire's profile, **Then** I see a visual progress bar indicating their overall completion percentage.
#         *   **Given** the new hire has completed a task, **When** I refresh my dashboard, **Then** the task list and progress bar are updated in near real-time.
#         *   **Given** a task requires my action (e.g., 'Approve equipment request'), **When** I view the dashboard, **Then** that task is clearly highlighted in a 'My Tasks' section.
#
# *   **Story 2.2:** As a Busy Hiring Manager, I want the tool to automatically suggest and help schedule critical introductory meetings, so that I don't forget these important connections and can save administrative time.
#     *   **Acceptance Criteria:**
#         *   **Given** my new hire's onboarding plan includes 'Schedule 1:1 with Manager', **When** I view this task, **Then** there is a 'Schedule Now' button that integrates with the company calendar.
#         *   **Given** I click 'Schedule Now', **When** the calendar interface opens, **Then** it shows mutually available time slots for me and my new hire.
#         *   **Given** I select a time and confirm, **When** the meeting is created, **Then** the calendar invitation is sent to both of us and includes a pre-populated agenda template with suggested talking points.
#         *   **Given** the meeting has been successfully scheduled, **When** I return to my dashboard, **Then** the 'Schedule 1:1' task is automatically marked as complete.
#
# ---
# **Epic: HR Admin Process Management**
#
# *   **Story 3.1:** As a Process-Driven HR Administrator, I want to create and customize role-based onboarding templates, so that I can ensure a consistent and relevant experience for every new hire across the company.
#     *   **Acceptance Criteria:**
#         *   **Given** I am an HR Admin logged into the admin panel, **When** I navigate to 'Onboarding Plans', **Then** I see a list of existing templates and a button to 'Create New Template'.
#         *   **Given** I am creating a new template for 'Sales Development Rep', **When** I add tasks, **Then** I can assign each task to a specific role (New Hire, Manager, IT, HR).
#         *   **Given** I have saved the template, **When** a new SDR is hired, **Then** I can assign the 'Sales Development Rep' template to their onboarding journey.
#         *   **Given** a process changes, **When** I edit an existing template, **Then** the changes are applied only to new hires assigned that template going forward, not those already in progress.
#
# ---
#
# ## 5. Non-Functional Requirements (NFRs)
# *The qualities of the system. These are just as important as the functional requirements.*
#
# - **Performance:** The application must load in under 3 seconds on a standard corporate network connection.
# - **Security:** All user data, especially PII, must be encrypted in transit and at rest. The system must comply with company SSO policies for authentication.
# - **Accessibility:** The user interface must be compliant with WCAG 2.1 AA standards to ensure usability for all employees.
# - **Scalability:** The system must support up to 500 concurrent users during peak onboarding seasons (e.g., post-university graduation hiring).
#
# ## 6. Release Plan & Milestones
# *A high-level timeline for delivery.*
#
# - **Version 1.0 (MVP):** [Target Date: Q1 End] - Core features establishing the basic workflow: digital paperwork submission, manager progress dashboard, and HR admin template creation. (Covers Stories 1.1, 2.1, 3.1)
# - **Version 1.1:** [Target Date: Q2 Mid] - Enhanced engagement features: "Meet the Team" profiles and calendar integration for automated meeting scheduling. (Covers Stories 1.2, 2.2)
# - **Version 2.0:** [Target Date: Q4 End] - Full social engagement and gamification elements to further enhance the new hire experience.
#
# ## 7. Out of Scope & Future Considerations
# *What this product is **not**. This section is critical for managing expectations and preventing scope creep.*
#
# **7.1. Out of Scope for V1.0:**
# - Direct integration with third-party HR payroll systems (data will be managed via CSV export/import initially).
# - A native mobile application (the web application will be mobile-responsive).
# - Advanced analytics dashboard for managers beyond basic completion tracking.
#
# **7.2. Future Work:**
# - Integration with the corporate Learning Management System (LMS) to assign initial training modules.
# - AI-powered personalized onboarding paths based on role and pre-hire survey results.
# - A buddy/mentorship assignment and tracking module.
#
# ## 8. Appendix & Open Questions
# *A place to track dependencies, assumptions, and questions that need answers.*
#
# - **Open Question:** Which team (HR or Hiring Manager) will be responsible for populating and maintaining the content in the "Meet Your Team" sections?
# - **Dependency:** The final UI/UX design mockups for the dashboard and paperwork hub are required from the Design team by [Date: 2 weeks from today].
# - **Assumption:** The company's standard calendar API (e.g., Google Calendar, Outlook) is available and accessible for the meeting scheduling integration.

# %% [markdown]
# ### Challenge 3 (Advanced): Programmatic Validation with Pydantic
#
# **Task:** We will now create a Pydantic model to represent the structure of our PRD. This allows us to programmatically validate any PRD, ensuring it meets our standards before it's accepted as a formal artifact.
#
# **Instructions:**
# 1.  Prompt the LLM to generate a Pydantic model that reflects the structure of the `prd_template.md`. The model should have fields for each major section (e.g., `introduction: str`, `user_personas: List[str]`, `user_stories: List[Dict]`).
# 2.  Save this generated model code to a file named `app/validation_models/prd_model.py`.
# 3.  While we won't write the full validation script in this lab, generating the Pydantic model itself is the key advanced step. It creates a reusable, code-based standard for our documentation.
#
# **Expected Quality:** A Python file containing a valid Pydantic model that can be used in the future to validate PRD documents automatically. This represents a shift from manual document review to automated governance.

# %%
# TWrite a prompt to generate a Pydantic model for the PRD.
# Tip: Be specific. Tell the LLM to create a class named 'ProductRequirementsDocument' and to use appropriate types from Python's 'typing' library.
pydantic_model_prompt = f"""
You are a Python developer specializing in data validation with Pydantic.

Based on the following markdown PRD template, generate a single Pydantic model class named `ProductRequirementsDocument` that represents its structure.

<prd_template>
{prd_template_content}
</prd_template>

The model should have fields that correspond to the main sections of the template. Use appropriate Python types (e.g., str, List, Dict) from the `typing` library.
Ensure you include the necessary imports from `pydantic` and `typing`.
Only output the raw Python code for the model, without any explanation.
"""


print("--- Generating Pydantic Model for PRD ---")
if prd_template_content:
    pydantic_model_code = get_completion(pydantic_model_prompt, client, model_name, api_provider)
    
    # Clean up the code if it's wrapped in markdown fences
    if '```' in pydantic_model_code:
        pydantic_model_code = pydantic_model_code.split('```')[1].lstrip('python').strip()
    
    print("\n--- Generated Pydantic Model ---")
    print(pydantic_model_code)

    # Save the generated Pydantic model code to a file.
    model_path = "app/validation_models/prd_model.py"
    save_artifact(pydantic_model_code, model_path, overwrite=True)
else:
    print("Skipping Pydantic model generation because template is missing.")

# Finally, save the completed PRD from the intermediate challenge
if prd_from_template_output:
    save_artifact(prd_from_template_output, "day1_prd.md", overwrite=True)
# Out:
# --- Generating Pydantic Model for PRD ---
#
# --- Generated Pydantic Model ---
# from typing import List, Dict
# from pydantic import BaseModel, Field
#
# class ProblemSection(BaseModel):
#     """Represents the 'Problem' section of the PRD."""
#     problem_statement: str = Field(
#         ...,
#         description="A clear and concise description of the primary problem the product solves."
#     )
#     user_personas: List[str] = Field(
#         ...,
#         description="A list of key user personas affected by the problem, e.g., 'The New Hire'."
#     )
#
# class SuccessMetric(BaseModel):
#     """Represents a single row in the 'Goals & Success Metrics' table."""
#     goal: str = Field(..., description="The high-level objective.")
#     kpi: str = Field(..., alias="Key Performance Indicator (KPI)", description="The metric used to measure the goal.")
#     target: str = Field(..., description="The specific, measurable target for the KPI.")
#
#     class Config:
#         allow_population_by_field_name = True
#
# class AcceptanceCriterion(BaseModel):
#     """Represents a single 'Given-When-Then' acceptance criterion for a user story."""
#     given: str = Field(..., description="The precondition for the test.")
#     when: str = Field(..., description="The action performed by the user.")
#     then: str = Field(..., description="The expected outcome or result.")
#
# class UserStory(BaseModel):
#     """Represents an Agile user story within an epic."""
#     story_id: str = Field(..., description="A unique identifier for the story, e.g., '1.1'.")
#     description: str = Field(
#         ...,
#         description="The user story in the format 'As a [persona], I want to [action], so that [benefit].'"
#     )
#     acceptance_criteria: List[AcceptanceCriterion] = Field(
#         ...,
#         description="A list of conditions that must be met for the story to be considered complete."
#     )
#
# class Epic(BaseModel):
#     """Represents a collection of related user stories."""
#     title: str = Field(..., description="The title of the epic, e.g., 'User Authentication'.")
#     user_stories: List[UserStory] = Field(..., description="A list of user stories belonging to this epic.")
#
# class Milestone(BaseModel):
#     """Represents a single release milestone in the release plan."""
#     version: str = Field(..., description="The version number for the release, e.g., '1.0 (MVP)'.")
#     target_date: str = Field(..., description="The target delivery date for this version.")
#     description: str = Field(..., description="A summary of the features included in this release.")
#
# class ScopeSection(BaseModel):
#     """Represents the 'Out of Scope & Future Considerations' section."""
#     out_of_scope: List[str] = Field(
#         ...,
#         alias="Out of Scope for V1.0",
#         description="A list of features or items explicitly not being built in the initial version."
#     )
#     future_work: List[str] = Field(
#         ...,
#         description="A list of potential features or integrations for future releases."
#     )
#
#     class Config:
#         allow_population_by_field_name = True
#
# class AppendixItem(BaseModel):
#     """Represents a single item in the appendix, such as an open question or a dependency."""
#     item_type: str = Field(..., description="The type of item, e.g., 'Open Question', 'Dependency'.")
#     description: str = Field(..., description="The full text of the question or dependency.")
#
#
# class ProductRequirementsDocument(BaseModel):
#     """
#     A Pydantic model representing a Product Requirements Document (PRD).
#     """
#     product_name: str = Field(..., description="The name of the product.")
#     status: str = Field(..., description="The current status of the document, e.g., 'Draft', 'In Review'.")
#     author: str = Field(..., description="The author or team responsible for the document.")
#     version: str = Field(..., description="The version of the document, e.g., '1.0'.")
#     last_updated: str = Field(..., description="The date the document was last updated.")
#
#     executive_summary_and_vision: str = Field(
#         ...,
#         description="A high-level overview of the product, its purpose, and its vision for success."
#     )
#     problem: ProblemSection = Field(
#         ...,
#         description="Details the problem statement and the user personas affected."
#     )
#     goals_and_success_metrics: List[SuccessMetric] = Field(
#         ...,
#         description="A list of specific, measurable outcomes to define success."
#     )
#     functional_requirements: List[Epic] = Field(
#         ...,
#         description="A breakdown of what the product must do, structured as epics and user stories."
#     )
#     non_functional_requirements: Dict[str, str] = Field(
#         ...,
#         description="A dictionary of system qualities, where the key is the category (e.g., 'Performance', 'Security')."
#     )
#     release_plan_and_milestones: List[Milestone] = Field(
#         ...,
#         description="A high-level timeline for delivery, broken down into versions and milestones."
#     )
#     scope_and_future_considerations: ScopeSection = Field(
#         ...,
#         description="Defines what is out of scope for the initial release and what is planned for the future."
#     )
#     appendix_and_open_questions: List[AppendixItem] = Field(
#         ...,
#         description="A list of dependencies, assumptions, and questions that need to be addressed."
#     )
#
# --- Generated Pydantic Model ---
# from typing import List, Dict
# from pydantic import BaseModel, Field
#
# class ProblemSection(BaseModel):
#     """Represents the 'Problem' section of the PRD."""
#     problem_statement: str = Field(
#         ...,
#         description="A clear and concise description of the primary problem the product solves."
#     )
#     user_personas: List[str] = Field(
#         ...,
#         description="A list of key user personas affected by the problem, e.g., 'The New Hire'."
#     )
#
# class SuccessMetric(BaseModel):
#     """Represents a single row in the 'Goals & Success Metrics' table."""
#     goal: str = Field(..., description="The high-level objective.")
#     kpi: str = Field(..., alias="Key Performance Indicator (KPI)", description="The metric used to measure the goal.")
#     target: str = Field(..., description="The specific, measurable target for the KPI.")
#
#     class Config:
#         allow_population_by_field_name = True
#
# class AcceptanceCriterion(BaseModel):
#     """Represents a single 'Given-When-Then' acceptance criterion for a user story."""
#     given: str = Field(..., description="The precondition for the test.")
#     when: str = Field(..., description="The action performed by the user.")
#     then: str = Field(..., description="The expected outcome or result.")
#
# class UserStory(BaseModel):
#     """Represents an Agile user story within an epic."""
#     story_id: str = Field(..., description="A unique identifier for the story, e.g., '1.1'.")
#     description: str = Field(
#         ...,
#         description="The user story in the format 'As a [persona], I want to [action], so that [benefit].'"
#     )
#     acceptance_criteria: List[AcceptanceCriterion] = Field(
#         ...,
#         description="A list of conditions that must be met for the story to be considered complete."
#     )
#
# class Epic(BaseModel):
#     """Represents a collection of related user stories."""
#     title: str = Field(..., description="The title of the epic, e.g., 'User Authentication'.")
#     user_stories: List[UserStory] = Field(..., description="A list of user stories belonging to this epic.")
#
# class Milestone(BaseModel):
#     """Represents a single release milestone in the release plan."""
#     version: str = Field(..., description="The version number for the release, e.g., '1.0 (MVP)'.")
#     target_date: str = Field(..., description="The target delivery date for this version.")
#     description: str = Field(..., description="A summary of the features included in this release.")
#
# class ScopeSection(BaseModel):
#     """Represents the 'Out of Scope & Future Considerations' section."""
#     out_of_scope: List[str] = Field(
#         ...,
#         alias="Out of Scope for V1.0",
#         description="A list of features or items explicitly not being built in the initial version."
#     )
#     future_work: List[str] = Field(
#         ...,
#         description="A list of potential features or integrations for future releases."
#     )
#
#     class Config:
#         allow_population_by_field_name = True
#
# class AppendixItem(BaseModel):
#     """Represents a single item in the appendix, such as an open question or a dependency."""
#     item_type: str = Field(..., description="The type of item, e.g., 'Open Question', 'Dependency'.")
#     description: str = Field(..., description="The full text of the question or dependency.")
#
#
# class ProductRequirementsDocument(BaseModel):
#     """
#     A Pydantic model representing a Product Requirements Document (PRD).
#     """
#     product_name: str = Field(..., description="The name of the product.")
#     status: str = Field(..., description="The current status of the document, e.g., 'Draft', 'In Review'.")
#     author: str = Field(..., description="The author or team responsible for the document.")
#     version: str = Field(..., description="The version of the document, e.g., '1.0'.")
#     last_updated: str = Field(..., description="The date the document was last updated.")
#
#     executive_summary_and_vision: str = Field(
#         ...,
#         description="A high-level overview of the product, its purpose, and its vision for success."
#     )
#     problem: ProblemSection = Field(
#         ...,
#         description="Details the problem statement and the user personas affected."
#     )
#     goals_and_success_metrics: List[SuccessMetric] = Field(
#         ...,
#         description="A list of specific, measurable outcomes to define success."
#     )
#     functional_requirements: List[Epic] = Field(
#         ...,
#         description="A breakdown of what the product must do, structured as epics and user stories."
#     )
#     non_functional_requirements: Dict[str, str] = Field(
#         ...,
#         description="A dictionary of system qualities, where the key is the category (e.g., 'Performance', 'Security')."
#     )
#     release_plan_and_milestones: List[Milestone] = Field(
#         ...,
#         description="A high-level timeline for delivery, broken down into versions and milestones."
#     )
#     scope_and_future_considerations: ScopeSection = Field(
#         ...,
#         description="Defines what is out of scope for the initial release and what is planned for the future."
#     )
#     appendix_and_open_questions: List[AppendixItem] = Field(
#         ...,
#         description="A list of dependencies, assumptions, and questions that need to be addressed."
#     )

# %% [markdown]
# ## Lab Conclusion
#
# Excellent work! You have now taken the structured user stories from the first lab and synthesized them into a formal Product Requirements Document. You also created a Pydantic model to enforce the structure of this document, introducing automated governance into your workflow. The `day1_prd.md` artifact will be the primary input for Day 2, where we will begin designing our system's architecture and database.
#
# > **Key Takeaway:** Using an LLM to populate a pre-defined template is a powerful pattern for creating consistent, high-quality documentation at scale. It combines the LLM's language skills with your required structure.
