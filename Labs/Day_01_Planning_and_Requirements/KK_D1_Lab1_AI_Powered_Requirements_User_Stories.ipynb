# %% [markdown]
# # Day 1 - Lab 1: AI-Powered Requirements & User Stories
#
# **Objective:** Use a Large Language Model (LLM) to decompose a vague problem statement into structured features, user personas, and Agile user stories, culminating in a machine-readable JSON artifact.
#
# **Estimated Time:** 90 minutes
#
# **Introduction:**
# Welcome to the first hands-on lab of the AI-Driven Software Engineering Program! All great software projects begin with a clear understanding of the problem to be solved. In this lab, you will take on the role of a tech lead or product manager and use an LLM as a co-pilot to transform a simple, high-level problem into a set of well-defined, actionable requirements. This process is fundamental to ensuring that the team builds the *right* product.
#
# For definitions of key terms used in this lab, please refer to the [GLOSSARY.md](../../GLOSSARY.md).

# %% [markdown]
# ## Step 1: Setup
#
# This initial block sets up our environment. It adds the project's root directory to the Python path, allowing us to import our custom `utils.py` script. We then initialize the connection to our Large Language Model (LLM).
#
# **Model Selection:**
# Our `utils.py` script is configured to work with multiple AI providers. You can change the `model_name` parameter in the `setup_llm_client()` function to any of the models listed in the `RECOMMENDED_MODELS` dictionary in `utils.py`. For example, to use a Hugging Face model, you could change the line to: `client, model_name, api_provider = setup_llm_client(model_name="meta-llama/Llama-3.3-70B-Instruct")`
#
# **Helper Functions Used:**
# - `setup_llm_client()`: To configure the API client for our chosen LLM.
# - `get_completion()`: To send a prompt to the LLM and get a response.
# - `save_artifact()`: To save our generated requirements to a file.

# %%
import sys
import os
import json

# Add the project's root directory to the Python path to ensure 'utils' can be imported.
try:
    # Assumes the notebook is in 'labs/Day_01_.../'
    project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
except IndexError:
    # Fallback for different execution environments
    project_root = os.path.abspath(os.path.join(os.getcwd()))

if project_root not in sys.path:
    sys.path.insert(0, project_root)

from utils import setup_llm_client, get_completion, save_artifact

# Initialize the LLM client. You can change the model here.
# For example: setup_llm_client(model_name="gemini-2.5-flash")
client, model_name, api_provider = setup_llm_client(model_name="gemini-2.5-pro")
# Out:
# 2025-10-27 16:59:33,655 ag_aisoftdev.utils INFO LLM Client configured provider=google model=gemini-2.5-pro latency_ms=None artifacts_path=None

# %% [markdown]
# ## Step 2: The Problem Statement
#
# Every project starts with a problem. Our problem is a common one in many organizations:
#
# > **"We need a tool to help our company's new hires get up to speed."**
#
# This statement is intentionally vague. Our job is to use the LLM to add structure and detail to it.

# %%
problem_statement = "We need a tool to help our company's new hires get up to speed."

# %% [markdown]
# ## Step 3: The Challenges
#
# Complete the following challenges in order. Each one builds upon the last, increasing in technical complexity and value.

# %% [markdown]
# ### Challenge 1 (Foundational): Brainstorming Features
#
# **Task:** Use the LLM to brainstorm a list of potential features and user personas based on the problem statement.
#
# **Instructions:**
# 1. Write a simple prompt that asks the LLM to brainstorm features for the onboarding tool.
# 2. Write a second prompt to identify three distinct user personas who would use this tool.
# 3. Run both prompts and review the markdown output.
#
# **Expected Quality:** The output should be a simple, readable markdown list of features and a description of the personas. This is a good first step but lacks the structure needed for automation.

# %%
# TCreate a string variable named 'features_prompt'.
# This prompt should ask the LLM to brainstorm features based on the problem_statement.
features_prompt = """ Brainstorm features for the onboarding tool that 
would help our company's new hires get up to speed """

print("--- Brainstorming Features ---")
brainstormed_features = get_completion(features_prompt, client, model_name, api_provider)
print(brainstormed_features)

# TCreate a string variable named 'personas_prompt'.
# This prompt should ask the LLM to identify three user personas based on the problem_statement.
personas_prompt = """ Identify three distinct user personas who would use 
the onboarding tool  """

print("\n--- Identifying User Personas ---")
user_personas = get_completion(personas_prompt, client, model_name, api_provider)
print(user_personas)
# Out:
# --- Brainstorming Features ---
# Of course! Here is a comprehensive brainstorm of features for a new hire onboarding tool, categorized to cover the entire journey from pre-boarding to full integration.
#
# ### Category 1: The Pre-Boarding Experience (Before Day 1)
# *Goal: Build excitement, reduce first-day anxiety, and handle logistics in advance.*
#
# *   **Digital Paperwork Portal:** Allow new hires to securely sign contracts, NDAs, and fill out HR/payroll forms online before their start date.
# *   **"Welcome Hub" Microsite:** A personalized landing page with:
#     *   A welcome video from the CEO and their direct manager.
#     *   A clear "First-Day Itinerary" (what time to arrive, where to go, who they'll meet).
#     *   Office map, dress code info, and transportation/parking details.
# *   **"Meet the Team" Section:** Photos, roles, and fun facts about their immediate team members and key contacts.
# *   **Company Culture Primer:** Short videos or articles on the company's mission, vision, and values.
# *   **Tech & Equipment Tracker:** A status page showing if their laptop has been ordered, software accounts created, etc.
# *   **Pre-Start Date Checklist:** A simple list of things for them to do, like "Upload a profile picture" or "Review the benefits overview."
#
# ---
#
# ### Category 2: The First Week - Structured Onboarding
# *Goal: Provide a clear, guided path to navigate the crucial first few days and weeks.*
#
# *   **Personalized Onboarding Plan/Checklist:**
#     *   A dynamic, day-by-day and week-by-week task list (e.g., "Day 1: Set up email signature," "Day 3: Complete security training").
#     *   Progress bars to show completion and create a sense of accomplishment.
#     *   Ability for managers to add custom, role-specific tasks.
# *   **Calendar Integration:** Automatically populates the new hire's calendar with essential meetings:
#     *   1:1s with their manager.
#     *   Team introductions.
#     *   HR orientation and benefits sessions.
#     *   Key departmental overviews.
# *   **"Who's Who" Interactive Org Chart:** A searchable directory where you can click on anyone to see their role, department, contact info, and a brief bio. Much more useful than a static chart.
# *   **Company Glossary & Acronym Buster:** A searchable database of internal jargon, project codenames, and acronyms to help them understand conversations faster.
#
# ---
#
# ### Category 3: Learning & Development
# *Goal: Deliver necessary knowledge in a digestible and engaging way.*
#
# *   **Centralized Knowledge Base:** A single source of truth for all onboarding documents, training videos, and how-to guides.
# *   **Role-Specific Learning Paths:** Curated modules and resources based on their role (e.g., an engineer gets access to the codebase setup guide, a salesperson gets the sales playbook).
# *   **Micro-learning Modules:** Short, interactive courses (5-10 mins) on topics like "Using our CRM," "Our Brand Voice," or "Submitting an Expense Report." Include short quizzes to check for understanding.
# *   **Skills & Competency Hub:** A section that outlines the core skills needed for their role and links to resources for developing them.
#
# ---
#
# ### Category 4: Social & Cultural Integration
# *Goal: Help new hires build relationships and feel like part of the team.*
#
# *   **Buddy Program Module:**
#     *   Automatically assigns a "Buddy" or "Onboarding Mentor."
#     *   Provides a checklist for the buddy and new hire (e.g., "Grab coffee," "Give an office tour," "Explain a team process").
# *   **"Coffee Chat" or "Donut" Integration:** A feature that randomly pairs the new hire with employees from other departments for informal virtual or in-person chats.
# *   **Interest Groups & Social Channels Directory:** A list of company Slack channels, clubs (e.g., running club, book club), and employee resource groups (ERGs) they can join.
# *   **New Hire Cohort Introduction:** A feature that connects all employees who started in the same week or month, creating a peer support group.
#
# ---
#
# ### Category 5: Manager & Team Tools
# *Goal: Empower managers to be great onboarding coaches.*
#
# *   **Manager Dashboard:** A view for managers to track their new hire's progress through the checklist, see completed tasks, and identify where they might be stuck.
# *   **Manager's Playbook:** Provides managers with templates and prompts for effective onboarding conversations, including:
#     *   First 1:1 agenda template.
#     *   30-60-90 day goal-setting framework.
#     *   Conversation starters for career development.
# *   **Team Collaboration Space:** A dedicated space for the new hire to ask their team questions, find team-specific documentation, and access project links.
#
# ---
#
# ### Category 6: Feedback & Performance
# *Goal: Ensure the new hire is on the right track and continuously improve the onboarding process.*
#
# *   **Pulse Check Surveys:** Short, automated surveys sent at key milestones (end of Week 1, Day 30, Day 90) asking "How are you feeling?" or "What could be better?"
# *   **30-60-90 Day Plan Tool:** A collaborative tool where the new hire and manager can define, track, and review goals for the first three months.
# *   **Feedback Hub:** A simple way for the new hire to provide feedback on the onboarding tool and process itself.
# *   **First Performance Review Prep:** A module that helps the new hire and manager prepare for their first formal check-in by summarizing accomplishments and goals from the 90-day plan.
#
# ---
#
# ### Category 7: Gamification & Engagement
# *Goal: Make the process more fun, engaging, and less of a chore.*
#
# *   **Points & Badges:** Award badges for completing key milestones (e.g., "First Week Finisher," "Compliance Champion," "Culture Pro").
# *   **Onboarding Leaderboard:** For a new hire cohort, show a friendly leaderboard based on module completion to encourage progress.
# *   **Personalized Welcome Message Wall:** A page where team members can leave welcome notes or GIFs for the new hire.
# *   **Automated Reminders & Notifications:** Smart notifications via email or Slack to keep the new hire (and their manager) on track without being overwhelming.
#
# --- Identifying User Personas ---
# Of course. Here are three distinct user personas for an employee onboarding tool, each representing a different role, set of goals, and pain points within the onboarding process.
#
# ---
#
# ### Persona 1: The New Hire
#
# **Name:** Amelia Chen, The Eager New Hire
# **Role:** Junior Marketing Specialist
# **Demographics:** 24 years old, recent graduate, tech-savvy, working remotely for the first time.
#
# **Bio:**
# Amelia is excited but nervous to start her first "real" job out of college. She wants to make a great impression and prove she was the right choice. She's worried about asking "stupid questions" and feeling lost in a sea of new names, processes, and software. Since she's remote, she's also anxious about connecting with her team and understanding the company culture from a distance.
#
# **Goals:**
# *   Get up to speed on her role and responsibilities as quickly as possible.
# *   Complete all necessary HR paperwork and IT setup without hassle.
# *   Understand the company's mission, values, and culture.
# *   Feel welcomed and connected to her manager and teammates.
# *   Find answers to her questions without having to constantly interrupt her busy manager.
#
# **Frustrations (Pain Points the Tool Solves):**
# *   **Information Overload:** Receiving dozens of emails on day one with attachments, links, and instructions is overwhelming.
# *   **Lack of Clarity:** Not knowing what the priority is—should she be filling out tax forms or reading the company handbook?
# *   **Social Isolation:** It's hard to meet people and get a "feel" for the company when you're not in an office.
# *   **Fear of Forgetting:** Worries she'll miss a critical compliance task or forget to sign an important document.
#
# **How She Uses the Onboarding Tool:**
# Amelia uses the tool as her single source of truth and a step-by-step guide. She logs in first thing on her first day to see a personalized checklist. She uses it to:
# *   Electronically sign her I-9 and W-4 forms.
# *   Watch a welcome video from the CEO.
# *   Find an org chart to see who's on her team.
# *   Complete mandatory security and compliance training modules.
# *   Get introduced to her assigned "onboarding buddy."
#
# ---
#
# ### Persona 2: The Hiring Manager
#
# **Name:** David Miller, The Busy Manager
# **Role:** Director of Marketing
# **Demographics:** 42 years old, manages a team of 8, juggles multiple high-priority projects, moderately tech-savvy.
#
# **Bio:**
# David is a seasoned manager who understands that a great onboarding experience is critical for retention and productivity. However, he is stretched thin with his own projects and team responsibilities. He doesn't have time to hand-hold a new hire through every single step. He needs a process that is consistent, efficient, and ensures nothing falls through the cracks.
#
# **Goals:**
# *   Get his new hire productive and contributing to team goals as fast as possible.
# *   Ensure the new hire has a positive and consistent experience.
# *   Integrate the new hire into the team's workflow and culture smoothly.
# *   Track the new hire's progress without constant micromanagement.
# *   Spend less time on administrative tasks and more time on strategic mentorship.
#
# **Frustrations (Pain Points the Tool Solves):**
# *   **Repetitive Work:** Hates having to remember and re-create a list of "first-week tasks" for every new person.
# *   **Lack of Visibility:** Doesn't know if the new hire has completed their HR paperwork or IT setup, leading him to ask redundant questions.
# *   **Inconsistency:** His last two hires had very different onboarding experiences because he was busier one time than the other.
# *   **Forgetting Key Steps:** Forgets to schedule crucial introductory meetings or a 30-day check-in.
#
# **How He Uses the Onboarding Tool:**
# David uses the tool as a management and tracking dashboard. He logs in a few times a week to:
# *   See a high-level view of Amelia's progress on both HR and team-specific tasks.
# *   Assign custom tasks like "Review the Q3 Marketing Plan" or "Set up a 1:1 with our lead designer."
# *   Receive automated reminders, like "Your new hire starts next week! Prepare their welcome kit."
# *   Approve requests or sign off on completed milestones.
#
# ---
#
# ### Persona 3: The HR Administrator
#
# **Name:** Sarah Jenkins, The Process Architect
# **Role:** People Operations Coordinator
# **Demographics:** 31 years old, highly organized, detail-oriented, comfortable with HR technology and systems.
#
# **Bio:**
# Sarah is the guardian of the company's employee experience. She is responsible for ensuring that every new hire—whether in engineering, sales, or marketing—has a smooth, compliant, and engaging onboarding. Her world revolves around process, scalability, and reporting. She is not just onboarding one person; she is managing the onboarding process for the entire company.
#
# **Goals:**
# *   Ensure 100% compliance with all legal and company policies for every new hire.
# *   Create a scalable and repeatable onboarding process that can be customized for different departments and roles.
# *   Reduce the administrative burden on herself, managers, and new hires.
# *   Gather feedback and data to continuously improve the onboarding experience.
# *   Report on key metrics like time-to-productivity and new hire satisfaction to leadership.
#
# **Frustrations (Pain Points the Tool Solves):**
# *   **Manual Follow-Up:** Spends hours chasing down new hires and managers for signed documents and completed forms.
# *   **Lack of Centralization:** Information is scattered across emails, spreadsheets, and shared drives, making it impossible to track progress effectively.
# *   **Inconsistent Experience:** The sales team's onboarding is completely different from the engineering team's, leading to inequity.
# *   **Reporting Nightmares:** It's incredibly difficult to pull data to show how effective the onboarding program is.
#
# **How She Uses the Onboarding Tool:**
# Sarah is a "power user" who lives in the tool's admin panel. She uses it to:
# *   Build and manage onboarding journey templates for different roles.
# *   Automate the distribution of forms, policies, and welcome messages.
# *   Run reports to see completion rates, identify bottlenecks, and track new hire feedback surveys.
# *   Integrate the onboarding tool with the company's other HR systems (like the HRIS and payroll).
# *   Update content and processes universally when a company policy changes.

# %% [markdown]
# ### Challenge 2 (Intermediate): Generating Formal User Stories
#
# **Task:** Now, let's increase the value by generating structured, formal Agile User Stories.
#
# **Instructions:**
# 1. Create a new, more sophisticated prompt.
# 2. This prompt should instruct the LLM to act as a Senior Product Manager.
# 3. It must use the brainstormed features and personas from the previous step as context.
# 4. The key instruction is to generate a list of user stories, each with detailed acceptance criteria in Gherkin format (`Given/When/Then`).
# 5. **Crucially, the prompt must demand the final output be a well-formed JSON array of objects.** Each object should represent a user story and have keys like `id`, `user_story`, `persona`, and `acceptance_criteria`.
#
# > **Tip:** If the LLM's output isn't perfect JSON, try making your prompt even more specific. You can tell it, 'Do not include any text before or after the JSON array. Your response must begin with [ and end with ].'
#
# **Expected Quality:** The output should not be markdown, but a clean, parsable JSON string. This is a significant step up in value, as a JSON artifact can be automatically processed by other systems (e.g., imported into Jira).

# %%
# TCreate a detailed prompt string named 'json_user_stories_prompt'.
# This prompt needs to instruct the LLM to act as a Senior Product Manager and convert the
# brainstormed features and personas into a structured JSON array of user stories.
# Tip: Be very specific about the required JSON format in your prompt instructions. Tell it what keys to use and what the data types should be.
json_user_stories_prompt = f""" 
You are a Senior Product Manager creating a product backlog for a new hire onboarding tool.

Based on the following context:
<context>
Problem Statement: {problem_statement}
Potential Features: {brainstormed_features}
User Personas: {user_personas}
</context>

Your task is to generate a list of 5 detailed user stories.

**OUTPUT REQUIREMENTS**:
- You MUST output a valid JSON array. Your response must begin with [ and end with ]. Do not include any text or markdown before or after the JSON array.
- Each object in the array must represent a single user story.
- Each object must have the following keys: 'id' (an integer), 'persona' (a string from the personas), 'user_story' (a string in the format 'As a [persona], I want [goal], so that [benefit].'), and 'acceptance_criteria' (an array of strings, with each string in Gherkin format 'Given/When/Then').
"""


print("--- Generating User Stories as JSON ---")
json_output_str = get_completion(json_user_stories_prompt, client, model_name, api_provider, temperature=0.2)

# Let's try to parse the JSON to see if the LLM followed instructions
try:
    # The LLM might wrap the JSON in markdown fences (```json ... ```).
    # We'll clean that up before parsing.
    if '```' in json_output_str:
        json_output_str = json_output_str.split('```')[1].lstrip('json').strip()
    
    user_stories_json = json.loads(json_output_str)
    print("Successfully parsed LLM output as JSON.")
    
    if user_stories_json:
        print("\n--- Sample User Story ---")
        print(json.dumps(user_stories_json[0], indent=2))
    else:
        print("JSON array is empty.")

except (json.JSONDecodeError, TypeError, IndexError) as e:
    print(f"Error: Failed to parse LLM output as JSON. Error: {e}")
    print("LLM Output was:\n", json_output_str)
    user_stories_json = []
# Out:
# --- Generating User Stories as JSON ---
# Successfully parsed LLM output as JSON.
#
# --- Sample User Story ---
# {
#   "id": 1,
#   "persona": "Amelia Chen, The Eager New Hire",
#   "user_story": "As an Eager New Hire, I want to securely complete and sign all my HR and payroll forms online before my start date, so that my first day is focused on integration and learning, not paperwork.",
#   "acceptance_criteria": [
#     "Given I have accepted my job offer, When I log into the Welcome Hub for the first time, Then I should see a 'Digital Paperwork' section with a list of required forms.",
#     "Given I am in the Digital Paperwork section, When I click on a form like the W-4, Then the form should open in a secure, fillable format within the tool.",
#     "Given I have filled out a form, When I click the 'Sign' button, Then I should be able to apply a legally binding e-signature.",
#     "Given I have submitted all required forms, When I return to my main onboarding checklist, Then the 'Complete Paperwork' task should be marked as complete."
#   ]
# }

# %% [markdown]
# ### Challenge 3 (Advanced): Programmatic Validation and Artifact Creation
#
# **Task:** Now for the highest-value step. Instead of just looking at the JSON, we will programmatically validate it and save it as a formal project artifact. This ensures reliability and prepares the requirements for automated use in later stages of the SDLC.
#
# **Instructions:**
# 1. Complete the `validate_and_save_stories` function below.
# 2. The function should iterate through the list of stories.
# 3. For each story, it must validate that the required keys are present and that the acceptance criteria list is not empty.
# 4. If all stories are valid, it should save the data to `artifacts/day1_user_stories.json`.
#
# **Expected Quality:** A robust script that guarantees the integrity of our requirements artifact. The final output is a validated `day1_user_stories.json` file in the `artifacts` directory, ready to be used as a reliable input for Day 2.

# %%
def validate_and_save_stories(stories_data):
    """Validates the structure of the user stories data and saves it if valid."""
    if not isinstance(stories_data, list) or not stories_data:
        print("Validation Failed: Data is not a non-empty list.")
        return

    required_keys = ['id', 'persona', 'user_story', 'acceptance_criteria']
    all_stories_valid = True

    # TImplement the validation logic inside this function.
    # 1. Loop through each story in the 'stories_data' list.
    # 2. For each story, check if it contains all the 'required_keys'.
    # 3. Also check if the 'acceptance_criteria' list is not empty.
    # 4. If a story is invalid, print an error message and set 'all_stories_valid' to False.
    #    (You can use 'continue' to skip to the next story).

    # Your validation code here

    # SLoop through each story object in the list.
    for i, story in enumerate(stories_data):
        # Check for the presence of all required keys.
        if not all(key in story for key in required_keys):
            print(f"Validation Failed: Story at index {i} is missing one or more required keys.")
            print(f"   Expected keys: {required_keys}")
            print(f"   Found keys: {list(story.keys()) if isinstance(story, dict) else 'Not a dictionary'}")
            all_stories_valid = False
            continue # Don't bother with further checks for this invalid story
        
        # Check that the acceptance criteria is a list with at least one item.
        ac = story.get('acceptance_criteria')
        if not isinstance(ac, list) or not ac:
            print(f"Validation Failed: Story at index {i} (ID: '{story.get('id')}') has invalid or empty acceptance criteria.")
            print(f"   Expected: list with at least one item")
            print(f"   Found: {type(ac)} with value {ac}")
            all_stories_valid = False
            
    # Only save the artifact if all stories in the list are valid.
    if all_stories_valid:
        print("\nAll user stories passed validation.")
        artifact_path = "artifacts/day1_user_stories.json"
        
        # TCall the save_artifact function from utils.py to save the data.
        # Remember to convert the Python list back to a JSON string using json.dumps().
        save_artifact(json.dumps(stories_data, indent=2), artifact_path)
        return True

    else:
        print("\nValidation failed. Artifact not saved.")
        return False

# Run the validation on the JSON data from the previous step
# if 'user_stories_json' in locals() and user_stories_json:
#     validate_and_save_stories(user_stories_json)
# else:
#     print("Skipping validation as user_stories_json is empty or not defined.")

# %% [markdown]
# ## Lab Conclusion
#
# Congratulations! You have completed the first lab. You started with a vague, one-sentence problem and finished with a structured, validated, machine-readable requirements artifact. This is the critical first step in an AI-assisted software development lifecycle. The `day1_user_stories.json` file you created will be the direct input for our next lab, where we will generate a formal Product Requirements Document (PRD).
#
# > **Key Takeaway:** The single most important skill demonstrated in this lab is turning unstructured ideas into structured, machine-readable data (JSON). This transformation is what enables automation and integration with other tools later in the SDLC.
